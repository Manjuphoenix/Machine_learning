# %%
from sklearn.linear_model import LinearRegression

# %%
import pandas
# Out:
# C:\Users\Manjunath D\anaconda3\lib\importlib\_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)

# %%
data = pandas.read_csv('SalaryData.csv')

# %%
experinence = data['YearsExperience']

# %%
salary = data['Salary']

# %%
Exp = experinence.values.reshape(30,1)

# %%
Sal = salary.values.reshape(30,1)

# %%
from sklearn.externals import joblib
# Out:
# C:\Users\Manjunath D\anaconda3\lib\site-packages\sklearn\externals\joblib\__init__.py:15: FutureWarning: sklearn.externals.joblib is deprecated in 0.21 and will be removed in 0.23. Please import this functionality directly from joblib, which can be installed with: pip install joblib. If this warning is raised when loading pickled models, you may need to re-serialize those models with scikit-learn 0.21+.
#   warnings.warn(msg, category=FutureWarning)

# %%
joblib.dump(model, 'salary.pk')
# Out:
# ['salary.pk']

# %%
model.predict([[10]])
